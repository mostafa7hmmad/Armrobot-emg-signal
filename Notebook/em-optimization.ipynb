# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix

# %%
df=pd.read_csv('/kaggle/input/emgsen/emg_dataset.csv')

# %%
df
# Out:
#        biceps  triceps  middle       label
# 0      1023.0     1023    1023  elbow_bend
# 1         0.0        0       0  elbow_bend
# 2      1023.0     1023    1023  elbow_bend
# 3         0.0        0       0  elbow_bend
# 4       944.0      442      65  elbow_bend
# ...       ...      ...     ...         ...
# 11590   745.0      737     681  hand_close
# 11591  1023.0     1023    1023  hand_close
# 11592    10.0        0       0  hand_close
# 11593     0.0        0       0  hand_close
# 11594     0.0        0       0  hand_close
#
# [11595 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11595 entries, 0 to 11594
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   biceps   11406 non-null  float64
#  1   triceps  11595 non-null  int64
#  2   middle   11595 non-null  int64
#  3   label    11595 non-null  object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 362.5+ KB

# %%
df.shape
# Out:
# (11595, 4)

# %%
df.isna().sum()
# Out:
# biceps     189
# triceps      0
# middle       0
# label        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 9109

# %%
df.drop_duplicates(inplace=True)

# %%
import pandas as pd
from sklearn.impute import KNNImputer


knn_data = df[['biceps']]  # 

imputer = KNNImputer(n_neighbors=5)

df[['biceps']] = imputer.fit_transform(knn_data)

# %%
df.isna().sum()
# Out:
# biceps     0
# triceps    0
# middle     0
# label      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (2486, 4)

# %%
columns = ['biceps', 'triceps', 'middle']
colors = ['blue', 'green', 'orange']

for col, color in zip(columns, colors):
    plt.figure(figsize=(6, 4))
    plt.boxplot(df[col].dropna(), patch_artist=True,
                boxprops=dict(facecolor=color, color=color),
                medianprops=dict(color='black'))
    plt.title(f'{col.capitalize()} - Boxplot')
    plt.ylabel('Value')
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt

columns = ['biceps', 'triceps', 'middle']
target = 'label'

for col in columns:
    plt.figure(figsize=(7, 4))
    plt.scatter(df[col], df[target], alpha=0.6)
    plt.title(f'{col.capitalize()} vs {target.capitalize()}')
    plt.xlabel(col.capitalize())
    plt.ylabel(target.capitalize())
    plt.grid(True)
    plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# الأعمدة اللي هنعمل لها Standardization
columns = ['biceps', 'triceps', 'middle']

# إنشاء نسخة من البيانات علشان منغيرش الأصلية
df_standardized = df.copy()

# إنشاء StandardScaler
scaler = StandardScaler()

# تطبيق الـ scaling
df_standardized[columns] = scaler.fit_transform(df[columns])

df_standardized[columns].head()
# Out:
#      biceps   triceps    middle
# 0  3.438778  3.235120  3.214303
# 1 -0.473790 -0.469855 -0.468072
# 4  3.136635  1.130926 -0.234099
# 5 -0.473790 -0.469855 -0.219701
# 6 -0.473790 -0.422773 -0.381682

# %%
columns = ['biceps', 'triceps', 'middle']
colors = ['blue', 'green', 'orange']

for col, color in zip(columns, colors):
    plt.figure(figsize=(6, 4))
    plt.boxplot(df_standardized[col].dropna(), patch_artist=True,
                boxprops=dict(facecolor=color, color=color),
                medianprops=dict(color='black'))
    plt.title(f'{col.capitalize()} - Boxplot')
    plt.ylabel('Value')
    plt.grid(True)
    plt.show()

# %%
from sklearn.preprocessing import PowerTransformer,MinMaxScaler

numeric_cols = df_standardized.select_dtypes(include=['number']).columns.tolist()
lower = df[numeric_cols].quantile(0.01)
upper = df[numeric_cols].quantile(0.99)
df_wins = df[numeric_cols].clip(lower=lower, upper=upper, axis=1)
pt = PowerTransformer(method='yeo-johnson')
df_pt = pd.DataFrame(
    pt.fit_transform(df_wins),
    columns=numeric_cols,
    index=df.index
)
others = df.drop(columns=numeric_cols)
df_final = pd.concat([df_pt, others], axis=1)
numeric_cols = df_final.select_dtypes(include=['number']).columns.tolist()


if not numeric_cols:
    raise ValueError("لا توجد أعمدة رقمية في DataFrame.")


for col in numeric_cols:

    p5 = df_final[col].quantile(0.05, interpolation='lower')  #  5%
    p95 = df_final[col].quantile(0.95, interpolation='higher')  #  95%
    
    df_final[col] = df_final[col].clip(lower=p5, upper=p95, axis=0)

# %%
plt.figure(figsize=(20, 6))
sns.boxplot(
    data=df_final,  
    showfliers=True,      
    flierprops=dict(marker='o', markerfacecolor='red', markersize=5, alpha=0.4),
    boxprops=dict(edgecolor='blue', linewidth=1.5),
    whiskerprops=dict(color='black', linewidth=1),
    capprops=dict(color='black', linewidth=1),
    medianprops=dict(color='green', linewidth=2)
)

plt.title('Boxplot After Preprocessing', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df_final.shape
# Out:
# (2486, 4)

# %%
import matplotlib.pyplot as plt

columns = ['biceps', 'triceps', 'middle']
target = 'label'

for col in columns:
    plt.figure(figsize=(7, 4))
    plt.scatter(df_final[col], df_final[target], alpha=0.6)
    plt.title(f'{col.capitalize()} vs {target.capitalize()}')
    plt.xlabel(col.capitalize())
    plt.ylabel(target.capitalize())
    plt.grid(True)
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df_final['label'] = le.fit_transform(df_final['label'])

# %%
df_final
# Out:
#          biceps   triceps    middle  label
# 0      1.688208  1.736851  1.701294      0
# 1     -1.208312 -1.258870 -1.203055      0
# 4      1.688208  1.418307  0.686946      0
# 5     -1.208312 -1.258870  0.710416      0
# 6     -1.208312 -0.019528  0.288192      0
# ...         ...       ...       ...    ...
# 11579  1.653679  1.689715  1.621036      2
# 11581  1.611925  1.560128  1.506209      2
# 11587  1.147573  1.593815  1.701294      2
# 11588  1.571226  1.648448  1.654313      2
# 11590  1.612909  1.614497  1.560723      2
#
# [2486 rows x 4 columns]

# %%
df_final.corr()['label']
# Out:
# biceps    -0.056996
# triceps   -0.004342
# middle     0.028629
# label      1.000000
# Name: label, dtype: float64

# %%
df_final.to_csv('preprosesseddata.csv')

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import Callback

y = to_categorical(df_final['label'], num_classes=len(np.unique(df_final['label'])))

X = df_final[['biceps', 'triceps', 'middle']].values  # اختر الأعمدة التي تحتوي على الميزات

SEQ_LEN = 10
X_seq, y_seq = [], []

for i in range(len(X) - SEQ_LEN):
    X_seq.append(X[i:i+SEQ_LEN])
    y_seq.append(y[i+SEQ_LEN])

X_seq = np.array(X_seq)
y_seq = np.array(y_seq)

print("X_seq shape:", X_seq.shape)
print("y_seq shape:", y_seq.shape)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_seq, y_seq,
    test_size=0.2,
    random_state=42,
    stratify=y_seq  
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Conv1D, MaxPooling1D, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential()

model.add(Conv1D(64, 3, activation='relu', input_shape=(SEQ_LEN, 3)))
model.add(MaxPooling1D(2))
model.add(Dropout(0.3))

model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.5))

model.add(LSTM(64, return_sequences=False))
model.add(Dropout(0.3))

model.add(BatchNormalization())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(len(np.unique(df_final['label'])), activation='softmax'))

model.compile(
optimizer=Adam(learning_rate=0.0005, clipnorm=1.0),
loss='categorical_crossentropy',
metrics=['accuracy']
)

model.summary()

class StopAt97Accuracy(Callback):
    def on_epoch_end(self, epoch, logs=None):
        if logs.get('val_accuracy') is not None and logs.get('val_accuracy') >= 0.97:
            print("\nValidation accuracy reached 97%, stopping training.")
            self.model.stop_training = True

# Create the callback
stop_at_97 = StopAt97Accuracy()
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=300,
    batch_size=32,
    callbacks=[stop_at_97]
)

model.save('model.h5')
# Out:
# X_seq shape: (2476, 10, 3)
# y_seq shape: (2476, 6)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_13 (Conv1D)                   │ (None, 8, 64)               │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_13 (MaxPooling1D)      │ (None, 4, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_58 (Dropout)                 │ (None, 4, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_29 (LSTM)                       │ (None, 4, 128)              │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_59 (Dropout)                 │ (None, 4, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_30 (LSTM)                       │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_60 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_13               │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_32 (Dense)                     │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_61 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_33 (Dense)                     │ (None, 6)                   │             390 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 153,670 (600.27 KB)
#  Trainable params: 153,542 (599.77 KB)
#  Non-trainable params: 128 (512.00 B)
# Epoch 1/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.1742 - loss: 2.0416 - val_accuracy: 0.2359 - val_loss: 1.7776
# Epoch 2/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2435 - loss: 1.7937 - val_accuracy: 0.2702 - val_loss: 1.7644
# Epoch 3/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2730 - loss: 1.7399 - val_accuracy: 0.3044 - val_loss: 1.7546
# Epoch 4/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3124 - loss: 1.6556 - val_accuracy: 0.3044 - val_loss: 1.7397
# Epoch 5/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3319 - loss: 1.6567 - val_accuracy: 0.3488 - val_loss: 1.7249
# Epoch 6/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3334 - loss: 1.6224 - val_accuracy: 0.3710 - val_loss: 1.6808
# Epoch 7/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3391 - loss: 1.5942 - val_accuracy: 0.4073 - val_loss: 1.6348
# Epoch 8/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3612 - loss: 1.5823 - val_accuracy: 0.4173 - val_loss: 1.5866
# Epoch 9/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3600 - loss: 1.5555 - val_accuracy: 0.4677 - val_loss: 1.5339
# Epoch 10/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3554 - loss: 1.5456 - val_accuracy: 0.4758 - val_loss: 1.4605
# Epoch 11/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3773 - loss: 1.5621 - val_accuracy: 0.4980 - val_loss: 1.4251
# Epoch 12/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3910 - loss: 1.5053 - val_accuracy: 0.5000 - val_loss: 1.4192
# Epoch 13/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3748 - loss: 1.5259 - val_accuracy: 0.4536 - val_loss: 1.3816
# Epoch 14/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4005 - loss: 1.4638 - val_accuracy: 0.4536 - val_loss: 1.3775
# Epoch 15/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4024 - loss: 1.4817 - val_accuracy: 0.4839 - val_loss: 1.3678
# Epoch 16/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3911 - loss: 1.5077 - val_accuracy: 0.5040 - val_loss: 1.3178
# Epoch 17/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4155 - loss: 1.4668 - val_accuracy: 0.5060 - val_loss: 1.2929
# Epoch 18/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4486 - loss: 1.4010 - val_accuracy: 0.5161 - val_loss: 1.2717
# Epoch 19/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4192 - loss: 1.4119 - val_accuracy: 0.5403 - val_loss: 1.2725
# Epoch 20/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4386 - loss: 1.4052 - val_accuracy: 0.5262 - val_loss: 1.2536
# Epoch 21/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4229 - loss: 1.4234 - val_accuracy: 0.5222 - val_loss: 1.2392
# Epoch 22/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4604 - loss: 1.3623 - val_accuracy: 0.5242 - val_loss: 1.2463
# Epoch 23/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4625 - loss: 1.3911 - val_accuracy: 0.5262 - val_loss: 1.2303
# Epoch 24/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4635 - loss: 1.3559 - val_accuracy: 0.5605 - val_loss: 1.2135
# Epoch 25/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4756 - loss: 1.3449 - val_accuracy: 0.5323 - val_loss: 1.2176
# Epoch 26/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4725 - loss: 1.3494 - val_accuracy: 0.5524 - val_loss: 1.1777
# Epoch 27/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4792 - loss: 1.3428 - val_accuracy: 0.5665 - val_loss: 1.1833
# Epoch 28/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4962 - loss: 1.3196 - val_accuracy: 0.5706 - val_loss: 1.1706
# Epoch 29/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4719 - loss: 1.3167 - val_accuracy: 0.5726 - val_loss: 1.1665
# Epoch 30/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4967 - loss: 1.2929 - val_accuracy: 0.5665 - val_loss: 1.1670
# Epoch 31/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5040 - loss: 1.2922 - val_accuracy: 0.5766 - val_loss: 1.1284
# Epoch 32/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4813 - loss: 1.2763 - val_accuracy: 0.5504 - val_loss: 1.1376
# Epoch 33/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5201 - loss: 1.2679 - val_accuracy: 0.5827 - val_loss: 1.1072
# Epoch 34/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5312 - loss: 1.2599 - val_accuracy: 0.5907 - val_loss: 1.0906
# Epoch 35/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4850 - loss: 1.2761 - val_accuracy: 0.6008 - val_loss: 1.0724
# Epoch 36/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5069 - loss: 1.2301 - val_accuracy: 0.6008 - val_loss: 1.0680
# Epoch 37/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5334 - loss: 1.2079 - val_accuracy: 0.5988 - val_loss: 1.0466
# Epoch 38/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5206 - loss: 1.2220 - val_accuracy: 0.5927 - val_loss: 1.0528
# Epoch 39/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5223 - loss: 1.2277 - val_accuracy: 0.6149 - val_loss: 1.0424
# Epoch 40/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5265 - loss: 1.2334 - val_accuracy: 0.6048 - val_loss: 1.0324
# Epoch 41/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5273 - loss: 1.1956 - val_accuracy: 0.6169 - val_loss: 1.0218
# Epoch 42/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5535 - loss: 1.1697 - val_accuracy: 0.6149 - val_loss: 1.0246
# Epoch 43/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5465 - loss: 1.1961 - val_accuracy: 0.6512 - val_loss: 1.0231
# Epoch 44/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5298 - loss: 1.1724 - val_accuracy: 0.6472 - val_loss: 0.9948
# Epoch 45/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5416 - loss: 1.1812 - val_accuracy: 0.6532 - val_loss: 0.9837
# Epoch 46/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5222 - loss: 1.1839 - val_accuracy: 0.6351 - val_loss: 0.9948
# Epoch 47/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5387 - loss: 1.1756 - val_accuracy: 0.6573 - val_loss: 0.9689
# Epoch 48/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5738 - loss: 1.1208 - val_accuracy: 0.6512 - val_loss: 0.9763
# Epoch 49/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5900 - loss: 1.1127 - val_accuracy: 0.6875 - val_loss: 0.9422
# Epoch 50/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5561 - loss: 1.1314 - val_accuracy: 0.6653 - val_loss: 0.9216
# Epoch 51/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5669 - loss: 1.1195 - val_accuracy: 0.6694 - val_loss: 0.9162
# Epoch 52/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5849 - loss: 1.0981 - val_accuracy: 0.6794 - val_loss: 0.9114
# Epoch 53/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5759 - loss: 1.0908 - val_accuracy: 0.6653 - val_loss: 0.9251
# Epoch 54/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5839 - loss: 1.0454 - val_accuracy: 0.6169 - val_loss: 0.9816
# Epoch 55/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5761 - loss: 1.0843 - val_accuracy: 0.6855 - val_loss: 0.8837
# Epoch 56/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5851 - loss: 1.0638 - val_accuracy: 0.6835 - val_loss: 0.8899
# Epoch 57/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5942 - loss: 1.0407 - val_accuracy: 0.6835 - val_loss: 0.8723
# Epoch 58/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5802 - loss: 1.0655 - val_accuracy: 0.7056 - val_loss: 0.8525
# Epoch 59/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6042 - loss: 1.0118 - val_accuracy: 0.6935 - val_loss: 0.8616
# Epoch 60/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6203 - loss: 0.9829 - val_accuracy: 0.6935 - val_loss: 0.8397
# Epoch 61/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6076 - loss: 1.0723 - val_accuracy: 0.7218 - val_loss: 0.8211
# Epoch 62/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6183 - loss: 0.9766 - val_accuracy: 0.7258 - val_loss: 0.8186
# Epoch 63/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6062 - loss: 1.0406 - val_accuracy: 0.7258 - val_loss: 0.7928
# Epoch 64/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6096 - loss: 1.0279 - val_accuracy: 0.7177 - val_loss: 0.8162
# Epoch 65/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6125 - loss: 1.0015 - val_accuracy: 0.7077 - val_loss: 0.7948
# Epoch 66/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6211 - loss: 0.9981 - val_accuracy: 0.6996 - val_loss: 0.7960
# Epoch 67/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6358 - loss: 0.9358 - val_accuracy: 0.7359 - val_loss: 0.7578
# Epoch 68/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6208 - loss: 1.0114 - val_accuracy: 0.7117 - val_loss: 0.7775
# Epoch 69/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6297 - loss: 0.9774 - val_accuracy: 0.7319 - val_loss: 0.7472
# Epoch 70/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6240 - loss: 0.9428 - val_accuracy: 0.7298 - val_loss: 0.7335
# Epoch 71/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6598 - loss: 0.8926 - val_accuracy: 0.7298 - val_loss: 0.7327
# Epoch 72/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6239 - loss: 0.9579 - val_accuracy: 0.7419 - val_loss: 0.7141
# Epoch 73/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6343 - loss: 0.9416 - val_accuracy: 0.7641 - val_loss: 0.6881
# Epoch 74/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6712 - loss: 0.8974 - val_accuracy: 0.7218 - val_loss: 0.7388
# Epoch 75/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6490 - loss: 0.9371 - val_accuracy: 0.7218 - val_loss: 0.7429
# Epoch 76/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6552 - loss: 0.8988 - val_accuracy: 0.7339 - val_loss: 0.7003
# Epoch 77/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6486 - loss: 0.8978 - val_accuracy: 0.7702 - val_loss: 0.6717
# Epoch 78/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6637 - loss: 0.8721 - val_accuracy: 0.7460 - val_loss: 0.6747
# Epoch 79/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6609 - loss: 0.8970 - val_accuracy: 0.7399 - val_loss: 0.7030
# Epoch 80/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6856 - loss: 0.8567 - val_accuracy: 0.7560 - val_loss: 0.6661
# Epoch 81/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7080 - loss: 0.8033 - val_accuracy: 0.7661 - val_loss: 0.6409
# Epoch 82/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6857 - loss: 0.8691 - val_accuracy: 0.7661 - val_loss: 0.6597
# Epoch 83/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6691 - loss: 0.8711 - val_accuracy: 0.7661 - val_loss: 0.6180
# Epoch 84/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6807 - loss: 0.8595 - val_accuracy: 0.7762 - val_loss: 0.6196
# Epoch 85/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6989 - loss: 0.7993 - val_accuracy: 0.7722 - val_loss: 0.6170
# Epoch 86/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7001 - loss: 0.8144 - val_accuracy: 0.7641 - val_loss: 0.6222
# Epoch 87/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6980 - loss: 0.8109 - val_accuracy: 0.8004 - val_loss: 0.6050
# Epoch 88/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6670 - loss: 0.8454 - val_accuracy: 0.7863 - val_loss: 0.6029
# Epoch 89/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6823 - loss: 0.8449 - val_accuracy: 0.7843 - val_loss: 0.6059
# Epoch 90/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7100 - loss: 0.7770 - val_accuracy: 0.7984 - val_loss: 0.5832
# Epoch 91/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7041 - loss: 0.8036 - val_accuracy: 0.7883 - val_loss: 0.5628
# Epoch 92/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7207 - loss: 0.7591 - val_accuracy: 0.7702 - val_loss: 0.5878
# Epoch 93/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7218 - loss: 0.7615 - val_accuracy: 0.8185 - val_loss: 0.5462
# Epoch 94/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7215 - loss: 0.7411 - val_accuracy: 0.7964 - val_loss: 0.5669
# Epoch 95/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7101 - loss: 0.7566 - val_accuracy: 0.7863 - val_loss: 0.5761
# Epoch 96/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7096 - loss: 0.7665 - val_accuracy: 0.8004 - val_loss: 0.5352
# Epoch 97/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7320 - loss: 0.7186 - val_accuracy: 0.8065 - val_loss: 0.5540
# Epoch 98/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7121 - loss: 0.7697 - val_accuracy: 0.8004 - val_loss: 0.5091
# Epoch 99/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7149 - loss: 0.7847 - val_accuracy: 0.8206 - val_loss: 0.5122
# Epoch 100/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7323 - loss: 0.7237 - val_accuracy: 0.8065 - val_loss: 0.5202
# Epoch 101/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7232 - loss: 0.7206 - val_accuracy: 0.8105 - val_loss: 0.5370
# Epoch 102/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7350 - loss: 0.7231 - val_accuracy: 0.8044 - val_loss: 0.5414
# Epoch 103/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7245 - loss: 0.7162 - val_accuracy: 0.8004 - val_loss: 0.5463
# Epoch 104/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7411 - loss: 0.6820 - val_accuracy: 0.8367 - val_loss: 0.5013
# Epoch 105/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7543 - loss: 0.6932 - val_accuracy: 0.8407 - val_loss: 0.5034
# Epoch 106/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7456 - loss: 0.7034 - val_accuracy: 0.8508 - val_loss: 0.4667
# Epoch 107/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7594 - loss: 0.6399 - val_accuracy: 0.8306 - val_loss: 0.4871
# Epoch 108/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7272 - loss: 0.7068 - val_accuracy: 0.8468 - val_loss: 0.4621
# Epoch 109/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7577 - loss: 0.6593 - val_accuracy: 0.8427 - val_loss: 0.4567
# Epoch 110/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7308 - loss: 0.6800 - val_accuracy: 0.8367 - val_loss: 0.4611
# Epoch 111/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7333 - loss: 0.6717 - val_accuracy: 0.8327 - val_loss: 0.4750
# Epoch 112/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7659 - loss: 0.6251 - val_accuracy: 0.8246 - val_loss: 0.4829
# Epoch 113/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7598 - loss: 0.6323 - val_accuracy: 0.8407 - val_loss: 0.4472
# Epoch 114/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7688 - loss: 0.6280 - val_accuracy: 0.8629 - val_loss: 0.4360
# Epoch 115/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7749 - loss: 0.6117 - val_accuracy: 0.8609 - val_loss: 0.4226
# Epoch 116/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7696 - loss: 0.6493 - val_accuracy: 0.8810 - val_loss: 0.4068
# Epoch 117/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7686 - loss: 0.6077 - val_accuracy: 0.8609 - val_loss: 0.4115
# Epoch 118/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7702 - loss: 0.6383 - val_accuracy: 0.8427 - val_loss: 0.4308
# Epoch 119/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7752 - loss: 0.5895 - val_accuracy: 0.8327 - val_loss: 0.4344
# Epoch 120/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7709 - loss: 0.6086 - val_accuracy: 0.8387 - val_loss: 0.4359
# Epoch 121/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7711 - loss: 0.5926 - val_accuracy: 0.8569 - val_loss: 0.4031
# Epoch 122/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7733 - loss: 0.5960 - val_accuracy: 0.8589 - val_loss: 0.3864
# Epoch 123/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7613 - loss: 0.6140 - val_accuracy: 0.8548 - val_loss: 0.4070
# Epoch 124/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7973 - loss: 0.5763 - val_accuracy: 0.8589 - val_loss: 0.4192
# Epoch 125/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7771 - loss: 0.5967 - val_accuracy: 0.8629 - val_loss: 0.3717
# Epoch 126/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7801 - loss: 0.5701 - val_accuracy: 0.8569 - val_loss: 0.3908
# Epoch 127/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8063 - loss: 0.5661 - val_accuracy: 0.8831 - val_loss: 0.3634
# Epoch 128/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8113 - loss: 0.5566 - val_accuracy: 0.8669 - val_loss: 0.3781
# Epoch 129/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8104 - loss: 0.5389 - val_accuracy: 0.8730 - val_loss: 0.3748
# Epoch 130/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8172 - loss: 0.5230 - val_accuracy: 0.8871 - val_loss: 0.3561
# Epoch 131/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8229 - loss: 0.4781 - val_accuracy: 0.8871 - val_loss: 0.3359
# Epoch 132/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8064 - loss: 0.4934 - val_accuracy: 0.8972 - val_loss: 0.3524
# Epoch 133/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8231 - loss: 0.5191 - val_accuracy: 0.8952 - val_loss: 0.3211
# Epoch 134/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8008 - loss: 0.5048 - val_accuracy: 0.8770 - val_loss: 0.3332
# Epoch 135/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8079 - loss: 0.5278 - val_accuracy: 0.8810 - val_loss: 0.3467
# Epoch 136/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8146 - loss: 0.5015 - val_accuracy: 0.8790 - val_loss: 0.3411
# Epoch 137/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8341 - loss: 0.4682 - val_accuracy: 0.8871 - val_loss: 0.3313
# Epoch 138/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8119 - loss: 0.5271 - val_accuracy: 0.8750 - val_loss: 0.3487
# Epoch 139/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8034 - loss: 0.5380 - val_accuracy: 0.8891 - val_loss: 0.3338
# Epoch 140/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8323 - loss: 0.5010 - val_accuracy: 0.8871 - val_loss: 0.3447
# Epoch 141/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8329 - loss: 0.4801 - val_accuracy: 0.8952 - val_loss: 0.3116
# Epoch 142/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8324 - loss: 0.4700 - val_accuracy: 0.8992 - val_loss: 0.3078
# Epoch 143/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8204 - loss: 0.4756 - val_accuracy: 0.8931 - val_loss: 0.3211
# Epoch 144/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8222 - loss: 0.5102 - val_accuracy: 0.8931 - val_loss: 0.3317
# Epoch 145/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8345 - loss: 0.4762 - val_accuracy: 0.9032 - val_loss: 0.3028
# Epoch 146/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8433 - loss: 0.4360 - val_accuracy: 0.8972 - val_loss: 0.3054
# Epoch 147/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8370 - loss: 0.4562 - val_accuracy: 0.9113 - val_loss: 0.2836
# Epoch 148/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8466 - loss: 0.4537 - val_accuracy: 0.9173 - val_loss: 0.2662
# Epoch 149/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8421 - loss: 0.4165 - val_accuracy: 0.8851 - val_loss: 0.3073
# Epoch 150/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8374 - loss: 0.4822 - val_accuracy: 0.9052 - val_loss: 0.2923
# Epoch 151/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8617 - loss: 0.4066 - val_accuracy: 0.9012 - val_loss: 0.2987
# Epoch 152/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8537 - loss: 0.4080 - val_accuracy: 0.9113 - val_loss: 0.2800
# Epoch 153/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8266 - loss: 0.4845 - val_accuracy: 0.9052 - val_loss: 0.2786
# Epoch 154/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8322 - loss: 0.4478 - val_accuracy: 0.9052 - val_loss: 0.2934
# Epoch 155/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8575 - loss: 0.4282 - val_accuracy: 0.9194 - val_loss: 0.2548
# Epoch 156/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8518 - loss: 0.3976 - val_accuracy: 0.8891 - val_loss: 0.3024
# Epoch 157/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8288 - loss: 0.4496 - val_accuracy: 0.9073 - val_loss: 0.2602
# Epoch 158/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8360 - loss: 0.4367 - val_accuracy: 0.9133 - val_loss: 0.2448
# Epoch 159/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8469 - loss: 0.4360 - val_accuracy: 0.9234 - val_loss: 0.2470
# Epoch 160/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8503 - loss: 0.4313 - val_accuracy: 0.9234 - val_loss: 0.2401
# Epoch 161/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8569 - loss: 0.4055 - val_accuracy: 0.8972 - val_loss: 0.2586
# Epoch 162/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8632 - loss: 0.3927 - val_accuracy: 0.9194 - val_loss: 0.2522
# Epoch 163/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8438 - loss: 0.4168 - val_accuracy: 0.9153 - val_loss: 0.2567
# Epoch 164/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8492 - loss: 0.4063 - val_accuracy: 0.9214 - val_loss: 0.2338
# Epoch 165/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8543 - loss: 0.3810 - val_accuracy: 0.9073 - val_loss: 0.2622
# Epoch 166/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8658 - loss: 0.3683 - val_accuracy: 0.9194 - val_loss: 0.2504
# Epoch 167/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8557 - loss: 0.3887 - val_accuracy: 0.9294 - val_loss: 0.2364
# Epoch 168/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8698 - loss: 0.3628 - val_accuracy: 0.9173 - val_loss: 0.2475
# Epoch 169/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8680 - loss: 0.3716 - val_accuracy: 0.9133 - val_loss: 0.2492
# Epoch 170/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8857 - loss: 0.3452 - val_accuracy: 0.9315 - val_loss: 0.2121
# Epoch 171/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8701 - loss: 0.3729 - val_accuracy: 0.9032 - val_loss: 0.2670
# Epoch 172/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8797 - loss: 0.3531 - val_accuracy: 0.8992 - val_loss: 0.2545
# Epoch 173/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8793 - loss: 0.3553 - val_accuracy: 0.9194 - val_loss: 0.2237
# Epoch 174/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8901 - loss: 0.3268 - val_accuracy: 0.9315 - val_loss: 0.2070
# Epoch 175/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8682 - loss: 0.3619 - val_accuracy: 0.8972 - val_loss: 0.2598
# Epoch 176/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8636 - loss: 0.4236 - val_accuracy: 0.9355 - val_loss: 0.2115
# Epoch 177/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8718 - loss: 0.3363 - val_accuracy: 0.9315 - val_loss: 0.2139
# Epoch 178/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8771 - loss: 0.3663 - val_accuracy: 0.9395 - val_loss: 0.2041
# Epoch 179/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8458 - loss: 0.3827 - val_accuracy: 0.9375 - val_loss: 0.2319
# Epoch 180/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8812 - loss: 0.3442 - val_accuracy: 0.9254 - val_loss: 0.2149
# Epoch 181/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8930 - loss: 0.3413 - val_accuracy: 0.9395 - val_loss: 0.1852
# Epoch 182/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8733 - loss: 0.3546 - val_accuracy: 0.9375 - val_loss: 0.2126
# Epoch 183/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8924 - loss: 0.2879 - val_accuracy: 0.9315 - val_loss: 0.1944
# Epoch 184/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8941 - loss: 0.2988 - val_accuracy: 0.9234 - val_loss: 0.2260
# Epoch 185/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8922 - loss: 0.3180 - val_accuracy: 0.9335 - val_loss: 0.1945
# Epoch 186/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8905 - loss: 0.3179 - val_accuracy: 0.9335 - val_loss: 0.1959
# Epoch 187/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8857 - loss: 0.3275 - val_accuracy: 0.9415 - val_loss: 0.1845
# Epoch 188/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8761 - loss: 0.3375 - val_accuracy: 0.9536 - val_loss: 0.1804
# Epoch 189/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8977 - loss: 0.3187 - val_accuracy: 0.9335 - val_loss: 0.1930
# Epoch 190/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8963 - loss: 0.3119 - val_accuracy: 0.9335 - val_loss: 0.1860
# Epoch 191/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8841 - loss: 0.3169 - val_accuracy: 0.9355 - val_loss: 0.1896
# Epoch 192/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8984 - loss: 0.2991 - val_accuracy: 0.9456 - val_loss: 0.1634
# Epoch 193/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9046 - loss: 0.2772 - val_accuracy: 0.9496 - val_loss: 0.1620
# Epoch 194/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9015 - loss: 0.3029 - val_accuracy: 0.9214 - val_loss: 0.2052
# Epoch 195/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8776 - loss: 0.3480 - val_accuracy: 0.9516 - val_loss: 0.1794
# Epoch 196/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8967 - loss: 0.2956 - val_accuracy: 0.9355 - val_loss: 0.1768
# Epoch 197/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8973 - loss: 0.2952 - val_accuracy: 0.9516 - val_loss: 0.1698
# Epoch 198/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9059 - loss: 0.2845 - val_accuracy: 0.9456 - val_loss: 0.1644
# Epoch 199/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8810 - loss: 0.3164 - val_accuracy: 0.9577 - val_loss: 0.1654
# Epoch 200/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9112 - loss: 0.2669 - val_accuracy: 0.9456 - val_loss: 0.1615
# Epoch 201/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9091 - loss: 0.2709 - val_accuracy: 0.9456 - val_loss: 0.1558
# Epoch 202/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8919 - loss: 0.3001 - val_accuracy: 0.9435 - val_loss: 0.1559
# Epoch 203/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9168 - loss: 0.2470 - val_accuracy: 0.9315 - val_loss: 0.1749
# Epoch 204/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9010 - loss: 0.2965 - val_accuracy: 0.9556 - val_loss: 0.1359
# Epoch 205/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9019 - loss: 0.2913 - val_accuracy: 0.9496 - val_loss: 0.1518
# Epoch 206/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9114 - loss: 0.2782 - val_accuracy: 0.9335 - val_loss: 0.1862
# Epoch 207/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9212 - loss: 0.2311 - val_accuracy: 0.9556 - val_loss: 0.1323
# Epoch 208/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9178 - loss: 0.2379 - val_accuracy: 0.9516 - val_loss: 0.1531
# Epoch 209/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8998 - loss: 0.2874 - val_accuracy: 0.9516 - val_loss: 0.1403
# Epoch 210/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9013 - loss: 0.2880 - val_accuracy: 0.9415 - val_loss: 0.1592
# Epoch 211/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9239 - loss: 0.2223 - val_accuracy: 0.9476 - val_loss: 0.1512
# Epoch 212/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9157 - loss: 0.2619 - val_accuracy: 0.9516 - val_loss: 0.1463
# Epoch 213/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9006 - loss: 0.2798 - val_accuracy: 0.9355 - val_loss: 0.1704
# Epoch 214/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8984 - loss: 0.3027 - val_accuracy: 0.9536 - val_loss: 0.1408
# Epoch 215/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9173 - loss: 0.2400 - val_accuracy: 0.9395 - val_loss: 0.1597
# Epoch 216/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9185 - loss: 0.2387 - val_accuracy: 0.9516 - val_loss: 0.1509
# Epoch 217/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9156 - loss: 0.2584 - val_accuracy: 0.9294 - val_loss: 0.1691
# Epoch 218/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9050 - loss: 0.2666 - val_accuracy: 0.9577 - val_loss: 0.1372
# Epoch 219/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9108 - loss: 0.2526 - val_accuracy: 0.9496 - val_loss: 0.1498
# Epoch 220/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9189 - loss: 0.2292 - val_accuracy: 0.9597 - val_loss: 0.1346
# Epoch 221/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9233 - loss: 0.2290 - val_accuracy: 0.9456 - val_loss: 0.1489
# Epoch 222/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9241 - loss: 0.2330 - val_accuracy: 0.9516 - val_loss: 0.1338
# Epoch 223/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9383 - loss: 0.2088 - val_accuracy: 0.9456 - val_loss: 0.1558
# Epoch 224/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9203 - loss: 0.2604 - val_accuracy: 0.9536 - val_loss: 0.1359
# Epoch 225/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9234 - loss: 0.2142 - val_accuracy: 0.9617 - val_loss: 0.1243
# Epoch 226/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9203 - loss: 0.2241 - val_accuracy: 0.9556 - val_loss: 0.1327
# Epoch 227/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9370 - loss: 0.1961 - val_accuracy: 0.9577 - val_loss: 0.1261
# Epoch 228/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9314 - loss: 0.2036 - val_accuracy: 0.9577 - val_loss: 0.1129
# Epoch 229/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9333 - loss: 0.2117 - val_accuracy: 0.9536 - val_loss: 0.1281
# Epoch 230/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9405 - loss: 0.1935 - val_accuracy: 0.9617 - val_loss: 0.1270
# Epoch 231/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9190 - loss: 0.2375 - val_accuracy: 0.9617 - val_loss: 0.1169
# Epoch 232/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9397 - loss: 0.1813 - val_accuracy: 0.9657 - val_loss: 0.0954
# Epoch 233/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9264 - loss: 0.2188 - val_accuracy: 0.9657 - val_loss: 0.1051
# Epoch 234/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9300 - loss: 0.2038 - val_accuracy: 0.9617 - val_loss: 0.1224
# Epoch 235/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9357 - loss: 0.1885 - val_accuracy: 0.9617 - val_loss: 0.1162
# Epoch 236/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9287 - loss: 0.2088 - val_accuracy: 0.9617 - val_loss: 0.1237
# Epoch 237/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9283 - loss: 0.2121 - val_accuracy: 0.9597 - val_loss: 0.1162
# Epoch 238/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9312 - loss: 0.1987 - val_accuracy: 0.9637 - val_loss: 0.1103
# Epoch 239/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9283 - loss: 0.2092 - val_accuracy: 0.9617 - val_loss: 0.1095
# Epoch 240/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9325 - loss: 0.1988 - val_accuracy: 0.9577 - val_loss: 0.1090
# Epoch 241/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9307 - loss: 0.2014 - val_accuracy: 0.9698 - val_loss: 0.0901
# Epoch 242/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9332 - loss: 0.2132 - val_accuracy: 0.9677 - val_loss: 0.0967
# Epoch 243/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9168 - loss: 0.2253 - val_accuracy: 0.9556 - val_loss: 0.1074
# Epoch 244/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9316 - loss: 0.2074 - val_accuracy: 0.9536 - val_loss: 0.1229
# Epoch 245/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9330 - loss: 0.2113 - val_accuracy: 0.9657 - val_loss: 0.1116
# Epoch 246/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9286 - loss: 0.1947 - val_accuracy: 0.9577 - val_loss: 0.1155
# Epoch 247/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9221 - loss: 0.2253 - val_accuracy: 0.9657 - val_loss: 0.0857
# Epoch 248/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9417 - loss: 0.1666 - val_accuracy: 0.9516 - val_loss: 0.1234
# Epoch 249/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9397 - loss: 0.1884 - val_accuracy: 0.9657 - val_loss: 0.0959
# Epoch 250/300
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9322 - loss: 0.1985
# Validation accuracy reached 97%, stopping training.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9324 - loss: 0.1983 - val_accuracy: 0.9798 - val_loss: 0.0766

# %%
import matplotlib.pyplot as plt

train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_accuracy, label='Training Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
